# %% [markdown]
# <a href="https://colab.research.google.com/github/maximilianjaeger/fashion_recommendations/blob/main/fashion_recommendations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Connect to Kaggle

# %%
# !pip install -q kaggle

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-3037c215-0a15-4ee0-b5f3-6922201e3a6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3037c215-0a15-4ee0-b5f3-6922201e3a6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c h-and-m-personalized-fashion-recommendations
# Out:
# ...
# 100% 28.7G/28.7G [03:42<00:00, 163MB/s]
# 100% 28.7G/28.7G [03:42<00:00, 139MB/s]

# %%
# !mkdir data

# %%
# !unzip h-and-m-personalized-fashion-recommendations.zip -d data

# %%
# !rm h-and-m-personalized-fashion-recommendations.zip

# %%
# !rm -r data/images

# %% [markdown]
# # Imports

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
# !pip install pandas-profiling[notebook]

# %%
import lux
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %% [markdown]
# # Data Loading
# - Ignore images
# - Load customers.csv
# - Load articles.csv

# %%
__articles = pd.read_csv("data/articles.csv")

# %%
__articles.columns
# Out:
# Index(['article_id', 'product_code', 'prod_name', 'product_type_no',
#        'product_type_name', 'product_group_name', 'graphical_appearance_no',
#        'graphical_appearance_name', 'colour_group_code', 'colour_group_name',
#        'perceived_colour_value_id', 'perceived_colour_value_name',
#        'perceived_colour_master_id', 'perceived_colour_master_name',
#        'department_no', 'department_name', 'index_code', 'index_name',
#        'index_group_no', 'index_group_name', 'section_no', 'section_name',
#        'garment_group_no', 'garment_group_name', 'detail_desc'],
#       dtype='object')

# %%
ProfileReport(__articles).to_file("articles.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
__customers = pd.read_csv("data/customers.csv")

# %%
__customers.columns
# Out:
# Index(['customer_id', 'FN', 'Active', 'club_member_status',
#        'fashion_news_frequency', 'age', 'postal_code'],
#       dtype='object')

# %%
ProfileReport(__customers).to_file("customers.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Feature Engineering
# - Ignore prod_name: high cardinality
